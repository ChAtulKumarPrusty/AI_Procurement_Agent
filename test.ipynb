# %%
from workflow.graph import graph
# Out:
# {'pdf_files': ['uploads/vendor1.pdf', 'uploads/vendor2.pdf'], 'raw_texts': ['Quotation\nVendor: ABC Technologies Pvt Ltd\nQuotation No: Q-ABC-1001\nDate: 23-Jul-2026\nItems: 10 Laptops @ I55,000 = I550,000\nSubtotal: 550000\nGST: 99000\nGrand Total: 649000\nDelivery: 10 Days\nPayment: 30 Days\nWarranty: 3 Years\nContact: Rahul Sharma\nEmail: sales@abctech.com\nPhone: 9876543210', 'Quotation\nVendor: XYZ Solutions Pvt Ltd\nQuotation No: Q-XYZ-2001\nDate: 23-Jul-2026\nItems: 10 Laptops @ I53,500 = I535,000\nSubtotal: 535000\nGST: 96300\nGrand Total: 631300\nDelivery: 15 Days\nPayment: 45 Days\nWarranty: 2 Years\nContact: Priya Singh\nEmail: sales@xyzsolutions.com\nPhone: 9123456780'], 'quotations': [{'vendor_name': 'ABC Technologies Pvt Ltd', 'quotation_number': 'Q-ABC-1001', 'quotation_date': '23-Jul-2026', 'currency': 'INR', 'subtotal': 550000, 'gst': 99000, 'grand_total': 649000, 'delivery_time': '10 Days', 'payment_terms': '30 Days', 'warranty': '3 Years', 'validity': None, 'contac
# ...

# %%
graph
